# %% [markdown]
# 95855 - Mbugua Rodney Kariuki

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
# %matplotlib inline
from sklearn.metrics import silhouette_score

# %%
data = pd.read_csv("data.csv")

# %%
data.columns
# Out:
# Index(['V1', 'V2'], dtype='object')

# %%
data.describe
# Out:
# <bound method NDFrame.describe of              V1         V2
# 0      2.072345  -3.241693
# 1     17.936710  15.784810
# 2      1.083576   7.319176
# 3     11.120670  14.406780
# 4     23.711550   2.557729
# 5     24.169930  32.024780
# 6     21.665780   4.892855
# 7      4.693684  12.342170
# 8     19.211910  -1.121366
# 9      4.230391  -4.441536
# 10     9.127130  23.605720
# 11     0.407503  15.297050
# 12     7.314846   3.309312
# 13    -3.438403 -12.025270
# 14    17.639350  -3.212345
# 15     4.415292  22.815550
# 16    11.941220   8.122487
# 17     0.725853   1.806819
# 18     8.185273  28.132600
# 19    -5.773587   1.024800
# 20    18.769430  24.169460
# 21     7.752016  -3.334991
# 22    10.611320  28.443780
# 23     2.021650  -4.687122
# 24     5.145525  11.186000
# 25     6.243310  19.477160
# 26   -11.706710   8.073185
# 27     7.255978  14.637040
# 28     3.392373   1.220712
# 29    24.299900  40.428870
# ...         ...        ...
# 2970  84.633760 -10.654310
# ...

# %%
data.isnull()
# Out:
#          V1     V2
# 0     False  False
# 1     False  False
# 2     False  False
# 3     False  False
# 4     False  False
# 5     False  False
# 6     False  False
# 7     False  False
# 8     False  False
# 9     False  False
# 10    False  False
# 11    False  False
# 12    False  False
# 13    False  False
# 14    False  False
# 15    False  False
# 16    False  False
# 17    False  False
# 18    False  False
# 19    False  False
# 20    False  False
# 21    False  False
# 22    False  False
# 23    False  False
# 24    False  False
# 25    False  False
# 26    False  False
# 27    False  False
# 28    False  False
# 29    False  False
# ...     ...    ...
# 2970  False  False
# 2971  False  False
# 2972  False  False
# 2973  False  False
# 2974  False  False
# 2975  False  False
# 2976  False  False
# 2977  False  False
# 2978  False  False
# 2979  False  False
# 2980  False  False
# 2981  False  False
# 2982  False  False
# 2983  False  False
# 2984  False  False
# ...

# %%
data.plot.scatter(x="V1", y="V2")

# %%
N = range(1,11)
for k in N:
    Kmean = KMeans(n_clusters=k).fit(data)
    Kmean.cluster_centers_
    data.plot.scatter(x="V1", y="V2", c="b")
    plt.scatter(9.4780459, 10.686052, s=50, c="g", marker="s")
    plt.scatter(40.68362784, 59.71589274, s=50, c="r", marker="s")
    plt.scatter(69.92418447, -10.11964119, s=50, c="orange", marker="s")
    plt.show()
    labels = Kmean.labels_

# %%
for k in N:
    Kmean = KMeans(n_clusters=k).fit(data)
    print(Kmean.cluster_centers_)
# Out:
# [[40.61135842 22.86214103]]
# [[ 26.97904841  38.42510047]
#  [ 69.49144971 -10.10803707]]
# [[  9.4780459   10.686052  ]
#  [ 69.92418447 -10.11964119]
#  [ 40.68362784  59.71589274]]
# [[ 31.66018919  60.11325756]
#  [ 69.92418447 -10.11964119]
#  [  9.45577774  10.66209744]
#  [ 48.00994577  59.34908062]]
# [[ 43.314742    51.4544369 ]
#  [ 64.14597442  -4.25583804]
#  [  9.3160955   10.62341254]
#  [ 38.39500054  66.52776229]
#  [ 75.86116482 -16.24064579]]
# [[ 69.58216965  -1.93621777]
#  [ 48.03326429  59.37952502]
#  [ 16.84011158  13.87222753]
#  [ 70.27789212 -18.58283978]
#  [ 31.67960468  60.24178194]
#  [  1.57628717   7.3039375 ]]
# [[ 46.17360827  67.89457553]
#  [ 63.50709755 -16.00950329]
#  [ 16.82810585  13.48240324]
#  [ 75.79946598  -4.82099096]
#  [  1.38954534   7.60875894]
#  [ 29.82560877  60.09212425]
#  [ 45.97144312  50.35200889]]
# [[ 45.35937217  50.43856484]
#  [ 80.56653816 -13.42200828]
#  [  1.47883001   7.33488314]
#  [ 29.72242375  60.78481354]
# ...

# %%
Sum_of_squared_distances = []
K = range(1,11)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(data)
    Sum_of_squared_distances.append(km.inertia_)

# %%
plt.plot(K, Sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum of squared distances')
plt.title('Elbow method for optimal k')
plt.show()

# %% [markdown]
# Final Kmeans model

# %%
Kmean_final = KMeans(n_clusters=3).fit(data)

# %%
Kmean_final.cluster_centers_
# Out:
# array([[ 40.68362784,  59.71589274],
#        [ 69.92418447, -10.11964119],
#        [  9.4780459 ,  10.686052  ]])

# %%
data.plot.scatter(x="V1", y="V2", c="b")
plt.scatter(9.4780459, 10.686052, s=50, c="g", marker="s")
plt.scatter(40.68362784, 59.71589274, s=50, c="r", marker="s")
plt.scatter(69.92418447, -10.11964119, s=50, c="orange", marker="s")
plt.show()

# %%
labels3 = Kmean3.labels_
print(labels3)
# Out:
# [0 0 0 ... 2 2 2]
